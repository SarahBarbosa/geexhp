# %% [markdown]
# ## Generating random planets dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from geexhp.core import datavis, datagen

# %%
dg = datagen.DataGen(url="http://127.0.0.1:3000/api.php")
# Out:
# Testing connection to PSG at http://127.0.0.1:3000/api.php ...
# Connected to PSG with success.

# %%
molweight = np.array([
    44.0095, 28.01340, 31.99880, 18.01528, 28.0101, 2.01588, 30.0690, 
    27.0253, 34.0809, 64.0638, 47.99820, 16.0425, 44.01280, 17.03052, 50.4875
    ])
dg.generator(1000, verbose=True, molweight=molweight, file="modern1k")
# Out:
# Gererating planets::  12%|█▏        | 1218/10000 [Remaining: 40:09:19, Elapsed: 5:34:09]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 5
#       1 molweight = np.array([
#       2     44.0095, 28.01340, 31.99880, 18.01528, 28.0101, 2.01588, 30.0690,
#       3     27.0253, 34.0809, 64.0638, 47.99820, 16.0425, 44.01280, 17.03052, 50.4875
#       4     ])
# ----> 5 dg.generator(10_000, verbose=True, molweight=molweight, file="test")
#
# File ~/Documentos/PSGCode/geexhp/core/datagen.py:104, in generator(self, nplanets, verbose, molweight, file)
#      98 def generator(self, nplanets: int, verbose: bool, molweight: list, file: str = "data") -> None:
#      99     """
#     100     Generates a dataset using the PSG for a specified number of planets
#     101     and saves it to a Parquet file.
#     102
#     103     Parameters
# --> 104     ----------
# ...

# %%
df = pd.read_parquet("../data/test.parquet")
index = np.random.randint(0, len(df))
datavis.plot_spectrum(df, label=f"index={index}", index=index);
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df = pd.read_parquet("../data/test.parquet")
#       2 index = np.random.randint(0, len(df))
#       3 datavis.plot_spectrum(df, label=f"index={index}", index=index);
#
# File ~/Documentos/PSGCode/psg-venv/lib/python3.10/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# ...
