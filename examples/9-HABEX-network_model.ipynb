# %% [markdown]
# # Setup

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import json
from scipy.stats import gaussian_kde

from typing import Any, Dict, Tuple, List, Optional

import tensorflow as tf
from sklearn.metrics import (
    r2_score,
    mean_squared_error,
    mean_absolute_error,
    median_absolute_error,
    explained_variance_score
)

import datetime

plt.rcParams.update({
    "xtick.top": False,
    "ytick.right": False,
    "xtick.direction": "out",
    "ytick.direction": "out",
    "font.size": 12,
    "axes.labelsize": 12,
    "axes.titlesize": 12,
    "legend.fontsize": 10,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
    "xtick.minor.visible": True,
    "ytick.minor.visible": True,
    "axes.spines.top": False,
    "axes.spines.right": False,
    "axes.grid" : True,
    "grid.color": "gray",
    "grid.linestyle": "--",
    "grid.linewidth": 0.5,
    "grid.alpha": 0.3,
})

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Mon Mar 10 01:06:00 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             44W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
def parse_example(
    example_proto: tf.Tensor,
    input_stats: Dict[str, Tuple[float, float]],
    output_stats: Dict[str, Any]
) -> Tuple[Dict[str, tf.Tensor], Dict[str, List[tf.Tensor]]]:
    """
    Parse a single tf.train.Example proto using provided normalization statistics.

    Parameters
    ----------
    example_proto : tf.Tensor
        A serialized Example proto containing raw features.
    input_stats : dict
        Normalization statistics for input features. Keys are regions ('UV', 'Vis', 'NIR')
        with corresponding tuples (mean, std).
    output_stats : dict
        Normalization and transformation statistics for output features.

    Returns
    -------
    tuple
        A tuple (normalized_inputs, grouped_outputs) where:
          - normalized_inputs is a dict mapping feature names to normalized tf.Tensor inputs.
          - grouped_outputs is a dict with keys 'physical_output', 'main_chemical_output',
            and 'other_chemical_output', each containing a list of processed output tensors.
    """
    # 1) Define raw feature schemas.
    raw_input_features = {
        'NOISY_ALBEDO_SS-NIR': tf.io.VarLenFeature(tf.float32),
        'NOISY_ALBEDO_SS-UV':  tf.io.VarLenFeature(tf.float32),
        'NOISY_ALBEDO_SS-Vis': tf.io.VarLenFeature(tf.float32),
    }

    raw_output_features = {
        # Planetary parameters.
        "OBJECT-RADIUS-REL-EARTH": tf.io.FixedLenFeature([], tf.float32),
        "OBJECT-GRAVITY":           tf.io.FixedLenFeature([], tf.float32),
        "ATMOSPHERE-TEMPERATURE":   tf.io.FixedLenFeature([], tf.float32),
        "ATMOSPHERE-PRESSURE":      tf.io.FixedLenFeature([], tf.float32),

        # Chemical abundances.
        'CH4':  tf.io.FixedLenFeature([], tf.float32),
        'CO':   tf.io.FixedLenFeature([], tf.float32),
        'CO2':  tf.io.FixedLenFeature([], tf.float32),
        'H2O':  tf.io.FixedLenFeature([], tf.float32),
        'N2':   tf.io.FixedLenFeature([], tf.float32),
        'N2O':  tf.io.FixedLenFeature([], tf.float32),
        'O2':   tf.io.FixedLenFeature([], tf.float32),
        'O3':   tf.io.FixedLenFeature([], tf.float32),

        # 'Earth_type': tf.io.FixedLenFeature([], tf.string)
    }

    # 2) Parse the example.
    all_features = {**raw_input_features, **raw_output_features}
    parsed = tf.io.parse_single_example(example_proto, all_features)

    # 3) Normalize input spectra.
    normalized_inputs = {}
    for region in ['UV', 'Vis', 'NIR']:
        spectrum = parsed[f'NOISY_ALBEDO_SS-{region}']
        if isinstance(spectrum, tf.SparseTensor):
            spectrum = tf.sparse.to_dense(spectrum, default_value=0.0)

        mean = input_stats[region][0]
        std  = input_stats[region][1]
        normalized = (spectrum - mean) / std

        # Reshape for model (example shape)
        if region == 'UV':
            normalized = tf.reshape(normalized, [7, 1])
        elif region == 'Vis':
            normalized = tf.reshape(normalized, [109, 1])
        elif region == 'NIR':
            normalized = tf.reshape(normalized, [25, 1])

        normalized_inputs[f'NOISY_ALBEDO_SS-{region}'] = normalized

    # 4) Process outputs.
    physical_outputs = []
    main_chemical_outputs = []
    other_chemical_outputs = []

    # 4a) Process planetary parameters (physical outputs).
    for param in ["OBJECT-RADIUS-REL-EARTH", "OBJECT-GRAVITY",
                    "ATMOSPHERE-TEMPERATURE", "ATMOSPHERE-PRESSURE"]:
        val = parsed[param]
        # To avoid a very ponctual error we found
        # the floating point precision error generates a single NaN value here :(
        if val == 273.15:
            val += 0.00002
        min_  = output_stats['physical_output_stats'][param][0]
        max_  = output_stats['physical_output_stats'][param][1]
        best_n  = output_stats['physical_output_stats'][param][2]
        processed = (val - min_) / (max_ - min_)
        processed = tf.math.pow(float(processed), float(1/best_n))
        physical_outputs.append(processed)

    # 4b) Process main chemical abundances.
    for chem in ['O2', 'O3']:
        val = parsed[chem]
        best_n = output_stats['chemical_output_stats'][chem]["best_n"]
        processed = tf.math.pow(float(val), float(1/best_n))
        main_chemical_outputs.append(processed)

    # 4c) Process other chemical abundances.
    for chem in ['CH4', 'CO', 'CO2', 'H2O', 'N2', 'N2O']:
        val = parsed[chem]
        best_n = output_stats['chemical_output_stats'][chem]["best_n"]
        processed = tf.math.pow(float(val), float(1 / best_n))
        other_chemical_outputs.append(processed)

    grouped_outputs = {
        'physical_output': physical_outputs,              # shape (4,)
        'main_chemical_output': main_chemical_outputs,    # shape (2,)
        'other_chemical_output': other_chemical_outputs,  # shape (7,)
        #'earth_type': parsed['Earth_type']               # shape (1,)
    }

    return normalized_inputs, grouped_outputs


def read_tfrecord(
    file_path: str,
    batch_size: int = 1024,
    shuffle_buffer: Optional[int] = None,
    repeat: bool = False
) -> tf.data.Dataset:
    """
    Read a TFRecord file, parse its examples, and return a batched tf.data.Dataset.

    Parameters
    ----------
    file_path : str
        Path to the TFRecord file.
    batch_size : int, optional
        Number of samples per batch, by default 256.
    shuffle_buffer : int, optional
        Buffer size for shuffling. If None or <= 0, shuffling is not applied.
    repeat : bool, optional
        Whether to repeat the dataset indefinitely, by default False.

    Returns
    -------
    tf.data.Dataset
        A dataset of parsed examples, batched and prefetched.
    """
    with open('/content/drive/MyDrive/dados/normalization_stats.json') as f:
        stats = json.load(f)

    # Create lookup dictionaries for input normalization statistics.
    input_stats = {
        'UV': (stats['inputs']['SS-UV']['mean'], stats['inputs']['SS-UV']['std']),
        'Vis': (stats['inputs']['SS-Vis']['mean'], stats['inputs']['SS-Vis']['std']),
        'NIR': (stats['inputs']['SS-NIR']['mean'], stats['inputs']['SS-NIR']['std'])
    }

    physical_keys = ["OBJECT-RADIUS-REL-EARTH", "OBJECT-GRAVITY",
                    "ATMOSPHERE-TEMPERATURE", "ATMOSPHERE-PRESSURE"]
    physical_output_stats = {
        key: (stats['outputs'][key]['min'], stats['outputs'][key]['max'], stats['outputs'][key]['best_n'])
        for key in physical_keys
    }

    chemical_keys = ['CH4', 'CO', 'CO2', 'H2O', 'N2', 'N2O', 'O2', 'O3']
    chemical_output_stats = {
        key: stats['outputs'][key] for key in chemical_keys
    }

    output_stats: Dict[str, Any] = {
        'physical_output_stats': physical_output_stats,
        'chemical_output_stats': chemical_output_stats
    }

    dataset = tf.data.TFRecordDataset(file_path, num_parallel_reads=tf.data.AUTOTUNE)

    if shuffle_buffer is not None and shuffle_buffer > 0:
        dataset = dataset.shuffle(buffer_size=shuffle_buffer)

    # Parse the dataset using the parse_example function.
    parsed_dataset = dataset.map(
        lambda x: parse_example(x, input_stats, output_stats),
        num_parallel_calls=tf.data.AUTOTUNE
    )

    if repeat:
        parsed_dataset = parsed_dataset.repeat()

    parsed_dataset = parsed_dataset.batch(batch_size, drop_remainder=False)
    parsed_dataset = parsed_dataset.prefetch(tf.data.AUTOTUNE)

    return parsed_dataset

# %%
train_ds = read_tfrecord("/content/drive/MyDrive/dados/train.tfrecord", shuffle_buffer=800000, repeat=True)
val_ds   = read_tfrecord("/content/drive/MyDrive/dados/val.tfrecord", shuffle_buffer=80000, repeat=True)
test_ds  = read_tfrecord("/content/drive/MyDrive/dados/test.tfrecord")

# %%
TRAIN_SAMPLES = 892073
VAL_SAMPLES = 107422
BATCH_SIZE = 1024

steps_per_epoch = math.ceil(TRAIN_SAMPLES / BATCH_SIZE)
validation_steps = math.ceil(VAL_SAMPLES / BATCH_SIZE)

# %% [markdown]
# # The best model

# %%
def residual_block_1D(x,
                      num_filters=32,
                      kernel_size=3,
                      activation='swish',
                      padding='same',
                      strides = 1
                      ):

    shortcut = x

    # First Conv
    y = tf.keras.layers.Conv1D(num_filters, kernel_size, padding=padding, activation=None)(x)
    y = tf.keras.layers.BatchNormalization()(y)
    y = tf.keras.layers.Activation(activation)(y)

    # Second Conv
    y = tf.keras.layers.Conv1D(num_filters, kernel_size, padding=padding, activation=None)(y)
    y = tf.keras.layers.BatchNormalization()(y)

    # Skip connection
    y = tf.keras.layers.Add()([shortcut, y])
    y = tf.keras.layers.Activation(activation)(y)

    y = tf.keras.layers.MaxPooling1D(pool_size=1)(y)

    y = tf.keras.layers.Conv1D(num_filters, kernel_size, padding=padding, strides=strides, activation=None)(y)

    return y

# %%
def small_transformer_block(x,
                            num_heads=4,
                            key_dim=32
                            ):

    # Self-Attention
    attn_output = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=key_dim)(x, x)
    x = tf.keras.layers.Add()([x, attn_output])
    x = tf.keras.layers.LayerNormalization()(x)

    # Feed-forward
    ff = tf.keras.layers.Dense(64, activation='swish')(x)
    ff = tf.keras.layers.Dense(x.shape[-1])(ff)  # project back to input feature dim
    x = tf.keras.layers.Add()([x, ff])
    x = tf.keras.layers.LayerNormalization()(x)

    return x

# %%
def build_model():
    """
    Creates a model with:
    - UV, VIS, NIR branches (each with conv+res+transformer)
    - Merged dense layers
    - Two sub-heads for (Physical parameters) and (Chemical abundances)
    """

    # ----------------------
    #  LISTS / CONSTANTS
    # ----------------------
    physical_targets = [
        "OBJECT-RADIUS-REL-EARTH",
        "OBJECT-GRAVITY",
        "ATMOSPHERE-TEMPERATURE",
        "ATMOSPHERE-PRESSURE"
    ]
    main_chemical_targets = ['O2', 'O3']
    other_chemical_targets = ['CH4', 'CO', 'CO2', 'H2O', 'N2', 'N2O']

    # -----------
    # INPUTS
    # -----------
    input_uv  = tf.keras.layers.Input(shape=(7, 1),  name='NOISY_ALBEDO_SS-UV')
    input_vis = tf.keras.layers.Input(shape=(109, 1), name='NOISY_ALBEDO_SS-Vis')
    input_nir = tf.keras.layers.Input(shape=(25, 1), name='NOISY_ALBEDO_SS-NIR')

    spectrum_lenghth = 141

    spectrum = tf.keras.layers.Concatenate(axis=1)([input_uv, input_vis, input_nir])

    # It's a near‐global coverage
    spectrum = residual_block_1D(spectrum, num_filters=20, kernel_size=int(spectrum_lenghth/4), strides=2)
    spectrum = residual_block_1D(spectrum, num_filters=20, kernel_size=int(spectrum_lenghth/2*4), strides=2)
    spectrum = small_transformer_block(spectrum, num_heads=2, key_dim=7)
    spectrum = tf.keras.layers.GlobalAveragePooling1D()(spectrum)

    shortcut = tf.keras.layers.Dense(32, kernel_initializer="he_normal")(spectrum)
    x = tf.keras.layers.Dropout(0.3)(shortcut)

    x = tf.keras.layers.Dense(32, kernel_initializer="he_normal")(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    x = tf.keras.layers.Dense(32, kernel_initializer="he_normal")(x)
    x = tf.keras.layers.Dropout(0.3)(x)

    x = tf.keras.layers.Add()([shortcut, x])

    # ------------------------
    #   SUB-HEADS
    # ------------------------
    # Physical parameters (4 outputs)
    phys = tf.keras.layers.Dense(16, kernel_initializer="glorot_uniform")(x)
    phys_out = tf.keras.layers.Dense(
        len(physical_targets),
        activation='sigmoid',
        name='physical_output'
    )(phys)

    # Chemical abundances (2 outputs) - use ReLU(max_value=1.0)
    main_chem = tf.keras.layers.Dense(16, kernel_initializer="he_normal")(x)
    main_chem_out_dense = tf.keras.layers.Dense(
        len(main_chemical_targets),
        activation=None,                  # no activation in Dense
        name='main_chem_dense'
    )(main_chem)
    main_chem_out = tf.keras.layers.ReLU(
        max_value=1.0,
        name='main_chemical_output'
    )(main_chem_out_dense)

    # Chemical abundances (6 outputs) - use ReLU(max_value=1.0)
    other_chem = tf.keras.layers.Dense(16, kernel_initializer="he_normal")(x)
    other_chem_out_dense = tf.keras.layers.Dense(
        len(other_chemical_targets),
        activation=None,
        name='other_chem_dense'
    )(other_chem)
    other_chem_out = tf.keras.layers.ReLU(
        max_value=1.0,
        name='other_chemical_output'
    )(other_chem_out_dense)

    # -----------
    # MODEL
    # -----------
    outputs = {
        'physical_output': phys_out,
        'main_chemical_output': main_chem_out,
        'other_chemical_output': other_chem_out
    }
    model = tf.keras.Model(
        inputs=[input_uv, input_vis, input_nir],
        outputs=outputs,
        name="Net22"
    )
    # ---------------------------
    #    LOSSES & COMPILATION
    # ---------------------------
    # We'll use 'mae' for both heads.
    # By default, Keras will average the MAE across each sub-head's dimension.
    losses = {
        'physical_output': 'mae',
        'main_chemical_output': 'mae',
        'other_chemical_output': 'mae'
    }

    loss_weights = {
        'physical_output': 1.0,
        'main_chemical_output': 2.0,
        'other_chemical_output': 1.5
    }

    opt = tf.keras.optimizers.Adam(learning_rate=1e-4)

    model.compile(
        optimizer=opt,
        loss=losses,
        loss_weights=loss_weights
    )

    return model

# %%
model = build_model()

if False:
    tf.keras.utils.plot_model(
    model,
    #to_file="network.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=True,
    dpi=200,
    show_layer_activations=True,
    show_trainable=True
    )

# %%
EPOCHS = 50

log_dir = "logs/fit23/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(
    log_dir=log_dir,
    histogram_freq=1
)

reduce_lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,       # How much to reduce LR by
    patience=3,       # Wait 3 epochs with no improvement before reducing LR
    min_lr=1e-7,      # Lower bound on LR
    cooldown=0,
    verbose=1
)

early_stop_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,       # Number of epochs with no improvement after which training stops
    restore_best_weights=True,  # Revert to the best weights found during training
    verbose=1
)

history = model.fit(
    train_ds,
    epochs=EPOCHS,
    steps_per_epoch=steps_per_epoch,
    validation_data=val_ds,
    validation_steps=validation_steps,
    callbacks=[
        tensorboard_callback,
        reduce_lr_callback,
        early_stop_callback
    ]
)
# Out:
# Epoch 1/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 115s 60ms/step - loss: 1.0230 - main_chemical_output_loss: 0.1802 - other_chemical_output_loss: 0.2741 - physical_output_loss: 0.2514 - val_loss: 0.4734 - val_main_chemical_output_loss: 0.0630 - val_other_chemical_output_loss: 0.0968 - val_physical_output_loss: 0.2021 - learning_rate: 1.0000e-04
# Epoch 2/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 47s 54ms/step - loss: 0.5248 - main_chemical_output_loss: 0.0769 - other_chemical_output_loss: 0.1168 - physical_output_loss: 0.1957 - val_loss: 0.3861 - val_main_chemical_output_loss: 0.0554 - val_other_chemical_output_loss: 0.0845 - val_physical_output_loss: 0.1486 - learning_rate: 1.0000e-04
# Epoch 3/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 47s 53ms/step - loss: 0.4300 - main_chemical_output_loss: 0.0644 - other_chemical_output_loss: 0.1002 - physical_output_loss: 0.1510 - val_loss: 0.3378 - val_main_chemical_output_loss: 0.0473 - val_other_chemical_output_loss: 0.0756 - val_physical_output_loss: 0.1297 - learning_rate: 1.0000e-04
# Epoch 4/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 46s 53ms/step - loss: 0.3766 - main_chemical_output_loss: 0.0547 - other_chemical_output_loss: 0.0861 - physical_output_loss: 0.1381 - val_loss: 0.3165 - val_main_chemical_output_loss: 0.0444 - val_other_chemical_output_loss: 0.0713 - val_physical_output_loss: 0.1206 - learning_rate: 1.0000e-04
# Epoch 5/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 82s 94ms/step - loss: 0.3430 - main_chemical_output_loss: 0.0488 - other_chemical_output_loss: 0.0775 - physical_output_loss: 0.1292 - val_loss: 0.3031 - val_main_chemical_output_loss: 0.0426 - val_other_chemical_output_loss: 0.0670 - val_physical_output_loss: 0.1175 - learning_rate: 1.0000e-04
# Epoch 6/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 46s 53ms/step - loss: 0.3199 - main_chemical_output_loss: 0.0452 - other_chemical_output_loss: 0.0714 - physical_output_loss: 0.1224 - val_loss: 0.2915 - val_main_chemical_output_loss: 0.0413 - val_other_chemical_output_loss: 0.0640 - val_physical_output_loss: 0.1130 - learning_rate: 1.0000e-04
# Epoch 7/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 47s 54ms/step - loss: 0.3025 - main_chemical_output_loss: 0.0425 - other_chemical_output_loss: 0.0671 - physical_output_loss: 0.1168 - val_loss: 0.2850 - val_main_chemical_output_loss: 0.0401 - val_other_chemical_output_loss: 0.0626 - val_physical_output_loss: 0.1109 - learning_rate: 1.0000e-04
# Epoch 8/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 47s 54ms/step - loss: 0.2901 - main_chemical_output_loss: 0.0406 - other_chemical_output_loss: 0.0643 - physical_output_loss: 0.1124 - val_loss: 0.2754 - val_main_chemical_output_loss: 0.0385 - val_other_chemical_output_loss: 0.0609 - val_physical_output_loss: 0.1070 - learning_rate: 1.0000e-04
# Epoch 9/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 44s 51ms/step - loss: 0.2820 - main_chemical_output_loss: 0.0393 - other_chemical_output_loss: 0.0624 - physical_output_loss: 0.1099 - val_loss: 0.2719 - val_main_chemical_output_loss: 0.0378 - val_other_chemical_output_loss: 0.0598 - val_physical_output_loss: 0.1065 - learning_rate: 1.0000e-04
# Epoch 10/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 45s 52ms/step - loss: 0.2761 - main_chemical_output_loss: 0.0384 - other_chemical_output_loss: 0.0611 - physical_output_loss: 0.1077 - val_loss: 0.2692 - val_main_chemical_output_loss: 0.0371 - val_other_chemical_output_loss: 0.0591 - val_physical_output_loss: 0.1064 - learning_rate: 1.0000e-04
# Epoch 11/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 78s 90ms/step - loss: 0.2719 - main_chemical_output_loss: 0.0378 - other_chemical_output_loss: 0.0600 - physical_output_loss: 0.1063 - val_loss: 0.2649 - val_main_chemical_output_loss: 0.0365 - val_other_chemical_output_loss: 0.0584 - val_physical_output_loss: 0.1043 - learning_rate: 1.0000e-04
# Epoch 12/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 44s 50ms/step - loss: 0.2684 - main_chemical_output_loss: 0.0372 - other_chemical_output_loss: 0.0592 - physical_output_loss: 0.1051 - val_loss: 0.2659 - val_main_chemical_output_loss: 0.0368 - val_other_chemical_output_loss: 0.0583 - val_physical_output_loss: 0.1049 - learning_rate: 1.0000e-04
# Epoch 13/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 78s 90ms/step - loss: 0.2654 - main_chemical_output_loss: 0.0368 - other_chemical_output_loss: 0.0585 - physical_output_loss: 0.1041 - val_loss: 0.2622 - val_main_chemical_output_loss: 0.0361 - val_other_chemical_output_loss: 0.0577 - val_physical_output_loss: 0.1035 - learning_rate: 1.0000e-04
# Epoch 14/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 46s 52ms/step - loss: 0.2630 - main_chemical_output_loss: 0.0364 - other_chemical_output_loss: 0.0580 - physical_output_loss: 0.1033 - val_loss: 0.2584 - val_main_chemical_output_loss: 0.0356 - val_other_chemical_output_loss: 0.0568 - val_physical_output_loss: 0.1020 - learning_rate: 1.0000e-04
# Epoch 15/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 40s 46ms/step - loss: 0.2610 - main_chemical_output_loss: 0.0360 - other_chemical_output_loss: 0.0575 - physical_output_loss: 0.1027 - val_loss: 0.2563 - val_main_chemical_output_loss: 0.0355 - val_other_chemical_output_loss: 0.0564 - val_physical_output_loss: 0.1008 - learning_rate: 1.0000e-04
# Epoch 16/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 81s 93ms/step - loss: 0.2593 - main_chemical_output_loss: 0.0358 - other_chemical_output_loss: 0.0571 - physical_output_loss: 0.1020 - val_loss: 0.2576 - val_main_chemical_output_loss: 0.0356 - val_other_chemical_output_loss: 0.0563 - val_physical_output_loss: 0.1021 - learning_rate: 1.0000e-04
# Epoch 17/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 27s 30ms/step - loss: 0.2580 - main_chemical_output_loss: 0.0356 - other_chemical_output_loss: 0.0568 - physical_output_loss: 0.1016 - val_loss: 0.2562 - val_main_chemical_output_loss: 0.0356 - val_other_chemical_output_loss: 0.0561 - val_physical_output_loss: 0.1007 - learning_rate: 1.0000e-04
# Epoch 18/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 32s 37ms/step - loss: 0.2560 - main_chemical_output_loss: 0.0352 - other_chemical_output_loss: 0.0564 - physical_output_loss: 0.1009 - val_loss: 0.2545 - val_main_chemical_output_loss: 0.0351 - val_other_chemical_output_loss: 0.0558 - val_physical_output_loss: 0.1004 - learning_rate: 1.0000e-04
# Epoch 19/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 44s 51ms/step - loss: 0.2552 - main_chemical_output_loss: 0.0351 - other_chemical_output_loss: 0.0562 - physical_output_loss: 0.1006 - val_loss: 0.2522 - val_main_chemical_output_loss: 0.0347 - val_other_chemical_output_loss: 0.0558 - val_physical_output_loss: 0.0991 - learning_rate: 1.0000e-04
# Epoch 20/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 44s 51ms/step - loss: 0.2542 - main_chemical_output_loss: 0.0350 - other_chemical_output_loss: 0.0560 - physical_output_loss: 0.1002 - val_loss: 0.2535 - val_main_chemical_output_loss: 0.0349 - val_other_chemical_output_loss: 0.0554 - val_physical_output_loss: 0.1005 - learning_rate: 1.0000e-04
# Epoch 21/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 44s 51ms/step - loss: 0.2531 - main_chemical_output_loss: 0.0348 - other_chemical_output_loss: 0.0558 - physical_output_loss: 0.0998 - val_loss: 0.2525 - val_main_chemical_output_loss: 0.0346 - val_other_chemical_output_loss: 0.0555 - val_physical_output_loss: 0.1001 - learning_rate: 1.0000e-04
# Epoch 22/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2519 - main_chemical_output_loss: 0.0346 - other_chemical_output_loss: 0.0555 - physical_output_loss: 0.0994
# Epoch 22: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 83s 96ms/step - loss: 0.2519 - main_chemical_output_loss: 0.0346 - other_chemical_output_loss: 0.0555 - physical_output_loss: 0.0994 - val_loss: 0.2524 - val_main_chemical_output_loss: 0.0347 - val_other_chemical_output_loss: 0.0552 - val_physical_output_loss: 0.1003 - learning_rate: 1.0000e-04
# Epoch 23/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 37s 43ms/step - loss: 0.2471 - main_chemical_output_loss: 0.0338 - other_chemical_output_loss: 0.0548 - physical_output_loss: 0.0974 - val_loss: 0.2468 - val_main_chemical_output_loss: 0.0339 - val_other_chemical_output_loss: 0.0545 - val_physical_output_loss: 0.0972 - learning_rate: 1.0000e-05
# Epoch 24/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 26s 29ms/step - loss: 0.2464 - main_chemical_output_loss: 0.0337 - other_chemical_output_loss: 0.0547 - physical_output_loss: 0.0969 - val_loss: 0.2465 - val_main_chemical_output_loss: 0.0339 - val_other_chemical_output_loss: 0.0545 - val_physical_output_loss: 0.0970 - learning_rate: 1.0000e-05
# Epoch 25/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 40s 46ms/step - loss: 0.2458 - main_chemical_output_loss: 0.0336 - other_chemical_output_loss: 0.0546 - physical_output_loss: 0.0966 - val_loss: 0.2465 - val_main_chemical_output_loss: 0.0339 - val_other_chemical_output_loss: 0.0544 - val_physical_output_loss: 0.0970 - learning_rate: 1.0000e-05
# Epoch 26/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 43s 49ms/step - loss: 0.2458 - main_chemical_output_loss: 0.0336 - other_chemical_output_loss: 0.0546 - physical_output_loss: 0.0967 - val_loss: 0.2462 - val_main_chemical_output_loss: 0.0339 - val_other_chemical_output_loss: 0.0544 - val_physical_output_loss: 0.0969 - learning_rate: 1.0000e-05
# Epoch 27/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 43s 50ms/step - loss: 0.2453 - main_chemical_output_loss: 0.0334 - other_chemical_output_loss: 0.0546 - physical_output_loss: 0.0967 - val_loss: 0.2461 - val_main_chemical_output_loss: 0.0339 - val_other_chemical_output_loss: 0.0544 - val_physical_output_loss: 0.0968 - learning_rate: 1.0000e-05
# Epoch 28/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 82s 95ms/step - loss: 0.2455 - main_chemical_output_loss: 0.0336 - other_chemical_output_loss: 0.0545 - physical_output_loss: 0.0966 - val_loss: 0.2463 - val_main_chemical_output_loss: 0.0339 - val_other_chemical_output_loss: 0.0544 - val_physical_output_loss: 0.0970 - learning_rate: 1.0000e-05
# Epoch 29/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 38s 44ms/step - loss: 0.2453 - main_chemical_output_loss: 0.0335 - other_chemical_output_loss: 0.0545 - physical_output_loss: 0.0965 - val_loss: 0.2458 - val_main_chemical_output_loss: 0.0338 - val_other_chemical_output_loss: 0.0544 - val_physical_output_loss: 0.0967 - learning_rate: 1.0000e-05
# Epoch 30/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 26s 30ms/step - loss: 0.2449 - main_chemical_output_loss: 0.0334 - other_chemical_output_loss: 0.0544 - physical_output_loss: 0.0964 - val_loss: 0.2459 - val_main_chemical_output_loss: 0.0338 - val_other_chemical_output_loss: 0.0543 - val_physical_output_loss: 0.0968 - learning_rate: 1.0000e-05
# Epoch 31/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 39s 44ms/step - loss: 0.2444 - main_chemical_output_loss: 0.0333 - other_chemical_output_loss: 0.0543 - physical_output_loss: 0.0963 - val_loss: 0.2458 - val_main_chemical_output_loss: 0.0339 - val_other_chemical_output_loss: 0.0543 - val_physical_output_loss: 0.0966 - learning_rate: 1.0000e-05
# Epoch 32/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2446 - main_chemical_output_loss: 0.0334 - other_chemical_output_loss: 0.0544 - physical_output_loss: 0.0963
# Epoch 32: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 83s 96ms/step - loss: 0.2446 - main_chemical_output_loss: 0.0334 - other_chemical_output_loss: 0.0544 - physical_output_loss: 0.0963 - val_loss: 0.2465 - val_main_chemical_output_loss: 0.0339 - val_other_chemical_output_loss: 0.0544 - val_physical_output_loss: 0.0971 - learning_rate: 1.0000e-05
# Epoch 33/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 37s 43ms/step - loss: 0.2442 - main_chemical_output_loss: 0.0333 - other_chemical_output_loss: 0.0544 - physical_output_loss: 0.0959 - val_loss: 0.2449 - val_main_chemical_output_loss: 0.0337 - val_other_chemical_output_loss: 0.0542 - val_physical_output_loss: 0.0963 - learning_rate: 1.0000e-06
# Epoch 34/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 25s 29ms/step - loss: 0.2443 - main_chemical_output_loss: 0.0334 - other_chemical_output_loss: 0.0544 - physical_output_loss: 0.0959 - val_loss: 0.2449 - val_main_chemical_output_loss: 0.0337 - val_other_chemical_output_loss: 0.0542 - val_physical_output_loss: 0.0963 - learning_rate: 1.0000e-06
# Epoch 35/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 39s 45ms/step - loss: 0.2437 - main_chemical_output_loss: 0.0332 - other_chemical_output_loss: 0.0543 - physical_output_loss: 0.0959 - val_loss: 0.2449 - val_main_chemical_output_loss: 0.0337 - val_other_chemical_output_loss: 0.0542 - val_physical_output_loss: 0.0963 - learning_rate: 1.0000e-06
# Epoch 36/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2437 - main_chemical_output_loss: 0.0333 - other_chemical_output_loss: 0.0543 - physical_output_loss: 0.0958
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1e-07.
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 84s 96ms/step - loss: 0.2437 - main_chemical_output_loss: 0.0333 - other_chemical_output_loss: 0.0543 - physical_output_loss: 0.0958 - val_loss: 0.2449 - val_main_chemical_output_loss: 0.0337 - val_other_chemical_output_loss: 0.0542 - val_physical_output_loss: 0.0963 - learning_rate: 1.0000e-06
# Epoch 37/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 27s 31ms/step - loss: 0.2436 - main_chemical_output_loss: 0.0332 - other_chemical_output_loss: 0.0542 - physical_output_loss: 0.0959 - val_loss: 0.2448 - val_main_chemical_output_loss: 0.0336 - val_other_chemical_output_loss: 0.0542 - val_physical_output_loss: 0.0963 - learning_rate: 1.0000e-07
# Epoch 38/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 40s 46ms/step - loss: 0.2436 - main_chemical_output_loss: 0.0332 - other_chemical_output_loss: 0.0543 - physical_output_loss: 0.0957 - val_loss: 0.2448 - val_main_chemical_output_loss: 0.0337 - val_other_chemical_output_loss: 0.0542 - val_physical_output_loss: 0.0963 - learning_rate: 1.0000e-07
# Epoch 39/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 37s 42ms/step - loss: 0.2435 - main_chemical_output_loss: 0.0332 - other_chemical_output_loss: 0.0542 - physical_output_loss: 0.0959 - val_loss: 0.2448 - val_main_chemical_output_loss: 0.0337 - val_other_chemical_output_loss: 0.0542 - val_physical_output_loss: 0.0963 - learning_rate: 1.0000e-07
# Epoch 40/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 84s 96ms/step - loss: 0.2436 - main_chemical_output_loss: 0.0333 - other_chemical_output_loss: 0.0543 - physical_output_loss: 0.0956 - val_loss: 0.2448 - val_main_chemical_output_loss: 0.0337 - val_other_chemical_output_loss: 0.0542 - val_physical_output_loss: 0.0963 - learning_rate: 1.0000e-07
# Epoch 41/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 26s 29ms/step - loss: 0.2436 - main_chemical_output_loss: 0.0332 - other_chemical_output_loss: 0.0543 - physical_output_loss: 0.0958 - val_loss: 0.2448 - val_main_chemical_output_loss: 0.0337 - val_other_chemical_output_loss: 0.0542 - val_physical_output_loss: 0.0963 - learning_rate: 1.0000e-07
# Epoch 42/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 42s 48ms/step - loss: 0.2435 - main_chemical_output_loss: 0.0331 - other_chemical_output_loss: 0.0543 - physical_output_loss: 0.0958 - val_loss: 0.2448 - val_main_chemical_output_loss: 0.0336 - val_other_chemical_output_loss: 0.0542 - val_physical_output_loss: 0.0963 - learning_rate: 1.0000e-07
# Epoch 42: early stopping
# Restoring model weights from the end of the best epoch: 37.

# %%
plt.plot(range(42), history.history["loss"], marker="o", label="train loss", color="k", markersize=4)
plt.plot(range(42), history.history["val_loss"], marker="o", label="validation loss", color="tab:gray", markersize=4)
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.legend();

# %%
plt.plot(range(42), history.history["main_chemical_output_loss"], marker="o", label="Train Main chemical output loss", color="k", markersize=4)
plt.plot(range(42), history.history["val_main_chemical_output_loss"], marker="o", label="Val Main chemical output loss", color="k", alpha=0.5, markersize=4)

plt.plot(range(42), history.history["other_chemical_output_loss"], marker="o", ls="dashed", label="Train Other chemical output loss", color="tab:gray", markersize=4)
plt.plot(range(42), history.history["val_other_chemical_output_loss"], marker="o", ls="dashed", label="Val Other chemical output loss", color="tab:gray", alpha=0.5, markersize=4)

plt.plot(range(42), history.history["physical_output_loss"], marker="o", ls="dotted", label="Train Physical output loss", color="tab:brown", markersize=4)
plt.plot(range(42), history.history["val_physical_output_loss"], marker="o", ls="dotted", label="Val Physical output loss", color="tab:brown", alpha=0.5, markersize=4)

plt.legend();

# %%
y_true_phys_all = []
y_true_main_chem_all = []
y_true_other_chem_all = []

y_pred_phys_all = []
y_pred_main_chem_all = []
y_pred_other_chem_all = []

for x_batch, y_batch in test_ds:
    # 1) Get model predictions for this batch
    predictions = model(x_batch, training=False)
    pred_phys_batch = predictions['physical_output']
    pred_main_chem_batch = predictions['main_chemical_output']
    pred_other_chem_batch = predictions['other_chemical_output']

    # 2) Collect ground-truth values
    true_phys_batch = y_batch['physical_output']
    true_main_chem_batch = y_batch['main_chemical_output']
    true_other_chem_batch = y_batch['other_chemical_output']

    # 3) Append to our running lists
    y_true_phys_all.append(true_phys_batch.numpy())
    y_true_main_chem_all.append(true_main_chem_batch.numpy())
    y_true_other_chem_all.append(true_other_chem_batch.numpy())

    y_pred_phys_all.append(pred_phys_batch.numpy())
    y_pred_main_chem_all.append(pred_main_chem_batch.numpy())
    y_pred_other_chem_all.append(pred_other_chem_batch.numpy())

# 4) Concatenate the list of batches into a single array for each head
y_true_phys_all = np.concatenate(y_true_phys_all, axis=0)
y_true_main_chem_all = np.concatenate(y_true_main_chem_all, axis=0)
y_true_other_chem_all = np.concatenate(y_true_other_chem_all, axis=0)

y_pred_phys_all = np.concatenate(y_pred_phys_all, axis=0)
y_pred_main_chem_all = np.concatenate(y_pred_main_chem_all, axis=0)
y_pred_other_chem_all = np.concatenate(y_pred_other_chem_all, axis=0)

# %%
physical_parameters = ['Radius', 'Gravity', 'Temperature', 'Pressure']
n_keys = len(physical_parameters)
n_cols = 2
n_rows = int(np.ceil(n_keys / n_cols))

plt.figure(figsize=(12, 10))

metrics_list = []

for i, phys_param in enumerate(physical_parameters):
    phys_true = np.array([y_true_phys_all[row][i] for row in range(len(y_true_phys_all))])
    phys_pred = np.array([y_pred_phys_all[row][i] for row in range(len(y_pred_phys_all))])

    min_val = min(phys_true.min(), phys_pred.min())
    max_val = max(phys_true.max(), phys_pred.max())

    r2 = r2_score(phys_true, phys_pred)

    ax = plt.subplot(n_rows, n_cols, i+1)
    ax.plot([min_val, max_val], [min_val, max_val], ls="--", color="tab:red", lw=2)

    # Compute density using a 2D histogram
    #nbins = 100
    #hist, xedges, yedges = np.histogram2d(phys_true, phys_pred, bins=nbins)
    # For each point, determine which bin it falls into
    #xidx = np.clip(np.searchsorted(xedges, phys_true) - 1, 0, nbins-1)
    #yidx = np.clip(np.searchsorted(yedges, phys_pred) - 1, 0, nbins-1)
    # Map each point to its density value (the count in its bin)
    #z = hist[xidx, yidx]

    #sc = ax.scatter(phys_true, phys_pred, c=z, s=5, cmap='Greys_r', edgecolor='none')
    ax.scatter(phys_true, phys_pred, s=10, edgecolor="tab:gray", linewidth=0.3, color="w")
    #cb = plt.colorbar(sc, ax=ax, pad=0)
    #cb.set_label("Density")

    ax.set_title(fr'{physical_parameters[i]} - $R^2$ score: {r2:.4f}')
    ax.set_xlabel("True Value")
    ax.set_ylabel("Pred Value")

    mse = mean_squared_error(phys_true, phys_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(phys_true, phys_pred)
    med_ae = median_absolute_error(phys_true, phys_pred)
    exp_var = explained_variance_score(phys_true, phys_pred)

    metrics_list.append({
        "Output": phys_param,
        "R²": r2,
        "Explained Variance": exp_var,
        "MSE": mse,
        "RMSE": rmse,
        "MAE": mae,
        "Median Absolute Error": med_ae
    })

df_metrics = pd.DataFrame(metrics_list)
plt.tight_layout();

# %%
df_metrics
# Out:
#         Output        R²  Explained Variance       MSE      RMSE       MAE  \
# 0       Radius  0.816598            0.816610  0.011861  0.108909  0.080352
# 1      Gravity  0.814172            0.814232  0.012045  0.109751  0.080733
# 2  Temperature  0.201306            0.202212  0.031420  0.177258  0.143916
# 3     Pressure  0.805152            0.805782  0.013117  0.114529  0.081593
#
#    Median Absolute Error
# 0               0.059947
# 1               0.060090
# 2               0.125414
# 3               0.057341

# %%
main_chemical_parameters = ['O2', 'O3']

n_keys = len(main_chemical_parameters)
n_cols = 2
n_rows = int(np.ceil(n_keys / n_cols))

plt.figure(figsize=(12, 6))

metrics_list = []

for i, chem_param in enumerate(main_chemical_parameters):
    chem_true = np.array([y_true_main_chem_all[row][i] for row in range(len(y_true_main_chem_all))])
    chem_pred = np.array([y_pred_main_chem_all[row][i] for row in range(len(y_pred_main_chem_all))])

    min_val = min(chem_true.min(), chem_pred.min())
    max_val = max(chem_true.max(), chem_pred.max())

    r2 = r2_score(chem_true, chem_pred)

    ax = plt.subplot(n_rows, n_cols, i+1)
    ax.plot([min_val, max_val], [min_val, max_val], ls="--", color="tab:red", lw=2)

    # Compute density using a 2D histogram
    #nbins = 50
    #hist, xedges, yedges = np.histogram2d(chem_true, chem_pred, bins=nbins)
    #xidx = np.clip(np.searchsorted(xedges, chem_true) - 1, 0, nbins-1)
    #yidx = np.clip(np.searchsorted(yedges, chem_pred) - 1, 0, nbins-1)
    #z = hist[xidx, yidx]

    # Scatter plot using density as color, with Greys_r cmap
    #sc = ax.scatter(chem_true, chem_pred, s=5, c=z, cmap='Greys_r', edgecolor="none", linewidth=0.3)
    ax.scatter(chem_true, chem_pred, s=10, edgecolor="tab:gray", linewidth=0.3, color="w")

    # Add colorbar with label "Density"
    #cb = plt.colorbar(sc, ax=ax, pad=0)
    #cb.set_label("Density")

    ax.set_title(fr'{main_chemical_parameters[i]} - $R^2$ score: {r2:.4f}')
    ax.set_xlabel("True Value")
    ax.set_ylabel("Pred Value")

    mse = mean_squared_error(chem_true, chem_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(chem_true, chem_pred)
    med_ae = median_absolute_error(chem_true, chem_pred)
    exp_var = explained_variance_score(chem_true, chem_pred)

    metrics_list.append({
        "Output": chem_param,
        "R²": r2,
        "Explained Variance": exp_var,
        "MSE": mse,
        "RMSE": rmse,
        "MAE": mae,
        "Median Absolute Error": med_ae
    })

df_metrics_chem = pd.DataFrame(metrics_list)
plt.tight_layout()
plt.show()

# %%
df_metrics_chem
# Out:
#   Output        R²  Explained Variance       MSE      RMSE       MAE  \
# 0     O2  0.835138            0.836146  0.014593  0.120800  0.062645
# 1     O3  0.955495            0.955562  0.001256  0.035436  0.011029
#
#    Median Absolute Error
# 0               0.020892
# 1               0.002697

# %%
other_chemical_parameters = ['CH4', 'CO', 'CO2', 'H2O', 'N2', 'N2O']

n_keys = len(other_chemical_parameters)
n_cols = 3
n_rows = 2
plt.figure(figsize=(14, 8))

metrics_list = []

for i, chem_param in enumerate(other_chemical_parameters):
    chem_true = np.array([y_true_other_chem_all[row][i] for row in range(len(y_true_other_chem_all))])
    chem_pred = np.array([y_pred_other_chem_all[row][i] for row in range(len(y_pred_other_chem_all))])

    # Correct min and max values using both true and pred arrays
    min_val = min(chem_true.min(), chem_pred.min())
    max_val = max(chem_true.max(), chem_pred.max())

    r2 = r2_score(chem_true, chem_pred)

    ax = plt.subplot(n_rows, n_cols, i+1)
    ax.plot([min_val, max_val], [min_val, max_val], ls="--", color="tab:red", lw=2)

    # Compute density with a 2D histogram
    #nbins = 100
    #hist, xedges, yedges = np.histogram2d(chem_true, chem_pred, bins=nbins)
    #xidx = np.clip(np.searchsorted(xedges, chem_true) - 1, 0, nbins-1)
    #yidx = np.clip(np.searchsorted(yedges, chem_pred) - 1, 0, nbins-1)
    #z = hist[xidx, yidx]

    # Create the scatter plot using density for the color (Greys_r)
    #sc = ax.scatter(chem_true, chem_pred, s=5, c=z, cmap='Greys_r', edgecolor="none", linewidth=0.3)
    ax.scatter(chem_true, chem_pred, s=10, edgecolor="tab:gray", linewidth=0.3, color="w")

    # Add a colorbar with label "Density"
    #cb = plt.colorbar(sc, ax=ax, pad=0)
    #cb.set_label("Density")

    ax.set_title(fr'{other_chemical_parameters[i]} - $R^2$ score: {r2:.4f}')
    ax.set_xlabel("True Value")
    ax.set_ylabel("Pred Value")

    mse = mean_squared_error(chem_true, chem_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(chem_true, chem_pred)
    med_ae = median_absolute_error(chem_true, chem_pred)
    exp_var = explained_variance_score(chem_true, chem_pred)

    metrics_list.append({
        "Output": chem_param,
        "R²": r2,
        "Explained Variance": exp_var,
        "MSE": mse,
        "RMSE": rmse,
        "MAE": mae,
        "Median Absolute Error": med_ae
    })

plt.tight_layout()

df_metrics_chem = pd.DataFrame(metrics_list)
plt.show()

# %%
df_metrics_chem
# Out:
#   Output        R²  Explained Variance       MSE      RMSE       MAE  \
# 0    CH4  0.852904            0.852941  0.003952  0.062868  0.041660
# 1     CO  0.690686            0.694436  0.005540  0.074434  0.053821
# 2    CO2  0.747935            0.750494  0.007839  0.088538  0.057940
# 3    H2O  0.792190            0.792566  0.003042  0.055150  0.036891
# 4     N2  0.692812            0.696449  0.032747  0.180962  0.108524
# 5    N2O  0.914570            0.914861  0.002611  0.051099  0.027585
#
#    Median Absolute Error
# 0               0.027882
# 1               0.039385
# 2               0.036998
# 3               0.024035
# 4               0.046350
# 5               0.016161

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/NN_22-01-colab-habex.keras')

# %% [markdown]
# # Bayesian tuner

# %%
# %%capture
# !pip install keras-tuner

import kerastuner as kt

# %%
def residual_block_1D(x,
                      num_filters=32,
                      kernel_size=3,
                      activation='swish',
                      padding='same',
                      strides=1):
    shortcut = x
    # First Conv
    y = tf.keras.layers.Conv1D(num_filters, kernel_size, padding=padding, activation=None)(x)
    y = tf.keras.layers.BatchNormalization()(y)
    y = tf.keras.layers.Activation(activation)(y)
    # Second Conv
    y = tf.keras.layers.Conv1D(num_filters, kernel_size, padding=padding, activation=None)(y)
    y = tf.keras.layers.BatchNormalization()(y)
    # Skip connection
    y = tf.keras.layers.Add()([shortcut, y])
    y = tf.keras.layers.Activation(activation)(y)
    y = tf.keras.layers.MaxPooling1D(pool_size=1)(y)
    y = tf.keras.layers.Conv1D(num_filters, kernel_size, padding=padding, strides=strides, activation=None)(y)
    return y

def small_transformer_block(x,
                            num_heads=4,
                            key_dim=32):
    # Self-Attention
    attn_output = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=key_dim)(x, x)
    x = tf.keras.layers.Add()([x, attn_output])
    x = tf.keras.layers.LayerNormalization()(x)
    # Feed-forward
    ff = tf.keras.layers.Dense(64, activation='swish')(x)
    ff = tf.keras.layers.Dense(x.shape[-1])(ff)  # project back to input feature dim
    x = tf.keras.layers.Add()([x, ff])
    x = tf.keras.layers.LayerNormalization()(x)
    return x

def build_model(hp):
    """
    HyperModel for your CNN with Bayesian optimization. The model:
      - Takes three spectral inputs (UV, VIS, NIR)
      - Merges them and applies two residual blocks with large kernel sizes for near-global coverage
      - Applies a small transformer block
      - Uses dense layers with dropout, and two sub-heads for physical and chemical outputs.
    """
    # ----------------------
    #  Target Definitions
    # ----------------------
    physical_targets = [
        "OBJECT-RADIUS-REL-EARTH",
        "OBJECT-GRAVITY",
        "ATMOSPHERE-TEMPERATURE",
        "ATMOSPHERE-PRESSURE"
    ]
    main_chemical_targets = ['O2', 'O3']
    other_chemical_targets = ['CH4', 'CO', 'CO2', 'H2O', 'N2', 'N2O']

    # ----------------------
    #   Input Layers
    # ----------------------
    input_uv  = tf.keras.layers.Input(shape=(7, 1),  name='NOISY_ALBEDO_SS-UV')
    input_vis = tf.keras.layers.Input(shape=(109, 1), name='NOISY_ALBEDO_SS-Vis')
    input_nir = tf.keras.layers.Input(shape=(25, 1), name='NOISY_ALBEDO_SS-NIR')
    # Concatenate along the spectral dimension.
    spectrum = tf.keras.layers.Concatenate(axis=1)([input_uv, input_vis, input_nir])
    spectrum_length = 141  # Total length (8 + 94 + 49)

    # ----------------------
    #   Hyperparameters
    # ----------------------
    # Convolutional block hyperparameters
    num_filters = hp.Int('num_filters', min_value=16, max_value=64, step=8, default=20)
    kernel_size_1 = hp.Choice('kernel_size_1',
                              values=[max(3, int(spectrum_length/4)), int(spectrum_length/3), int(spectrum_length/2)],
                              default=int(spectrum_length/4))
    kernel_size_2 = hp.Choice('kernel_size_2',
                              values=[int(spectrum_length/2), int(spectrum_length*0.75), spectrum_length],
                              default=int(spectrum_length/2))
    # Transformer block hyperparameters
    num_heads = hp.Int('num_heads', min_value=2, max_value=4, step=1, default=2)
    key_dim = hp.Int('key_dim', min_value=8, max_value=16, step=4, default=8)
    # Dense block and dropout hyperparameters
    dense_units = hp.Int('dense_units', min_value=16, max_value=64, step=16, default=32)
    dropout_rate = hp.Float('dropout_rate', min_value=0.1, max_value=0.5, step=0.1, default=0.3)
    # Optimizer learning rate
    learning_rate = hp.Float('learning_rate', min_value=1e-5, max_value=1e-3, sampling='LOG', default=1e-4)

    # ----------------------
    #   Model Architecture
    # ----------------------
    # Residual blocks with large kernels for near-global coverage.
    spectrum = residual_block_1D(spectrum,
                                 num_filters=num_filters,
                                 kernel_size=kernel_size_1,
                                 strides=2)
    spectrum = residual_block_1D(spectrum,
                                 num_filters=num_filters,
                                 kernel_size=kernel_size_2,
                                 strides=2)
    # Transformer block
    spectrum = small_transformer_block(spectrum, num_heads=num_heads, key_dim=key_dim)
    # Global pooling to reduce dimensionality.
    spectrum = tf.keras.layers.GlobalAveragePooling1D()(spectrum)

    # Dense layers with skip connection.
    shortcut = tf.keras.layers.Dense(dense_units, kernel_initializer="he_normal")(spectrum)
    x = tf.keras.layers.Dropout(dropout_rate)(shortcut)
    x = tf.keras.layers.Dense(dense_units, kernel_initializer="he_normal")(x)
    x = tf.keras.layers.Dropout(dropout_rate)(x)
    x = tf.keras.layers.Dense(dense_units, kernel_initializer="he_normal")(x)
    x = tf.keras.layers.Dropout(dropout_rate)(x)
    x = tf.keras.layers.Add()([shortcut, x])

    # ----------------------
    #   Sub-heads for Outputs
    # ----------------------
    # Physical parameters head (4 outputs)
    phys = tf.keras.layers.Dense(dense_units // 2, kernel_initializer="glorot_uniform")(x)
    phys_out = tf.keras.layers.Dense(
        len(physical_targets),
        activation='sigmoid',
        name='physical_output'
    )(phys)

    # Main chemical abundances head (2 outputs)
    main_chem = tf.keras.layers.Dense(dense_units // 2, kernel_initializer="he_normal")(x)
    main_chem_out_dense = tf.keras.layers.Dense(
        len(main_chemical_targets),
        activation=None,
        name='main_chem_dense'
    )(main_chem)
    main_chem_out = tf.keras.layers.ReLU(max_value=1.0, name='main_chemical_output')(main_chem_out_dense)

    # Other chemical abundances head (6 outputs)
    other_chem = tf.keras.layers.Dense(dense_units // 2, kernel_initializer="he_normal")(x)
    other_chem_out_dense = tf.keras.layers.Dense(
        len(other_chemical_targets),
        activation=None,
        name='other_chem_dense'
    )(other_chem)
    other_chem_out = tf.keras.layers.ReLU(max_value=1.0, name='other_chemical_output')(other_chem_out_dense)

    outputs = {
        'physical_output': phys_out,
        'main_chemical_output': main_chem_out,
        'other_chemical_output': other_chem_out
    }

    model = tf.keras.Model(
        inputs=[input_uv, input_vis, input_nir],
        outputs=outputs,
        name="Net22_hyper"
    )

    # ----------------------
    #   Compilation
    # ----------------------
    losses = {
        'physical_output': 'mae',
        'main_chemical_output': 'mae',
        'other_chemical_output': 'mae'
    }
    loss_weights = {
        'physical_output': 1.0,
        'main_chemical_output': 2.0,
        'other_chemical_output': 1.5
    }
    opt = tf.keras.optimizers.Adam(learning_rate=learning_rate)

    model.compile(
        optimizer=opt,
        loss=losses,
        loss_weights=loss_weights
    )

    return model

# %%
tuner = kt.BayesianOptimization(
    build_model,
    objective="val_loss",
    max_trials=10,
    directory="hyper_tuning_habex",
    project_name="net22_bayesian"
)

# %%
tuner.search(train_ds, epochs=2, validation_data=val_ds, steps_per_epoch=steps_per_epoch, validation_steps=validation_steps)
# Out:
# Trial 10 Complete [00h 02m 44s]
# val_loss: 0.30993032455444336
#
# Best val_loss So Far: 0.28548896312713623
# Total elapsed time: 00h 24m 59s

# %%
best_hp = tuner.get_best_hyperparameters(num_trials=1)[0]
display("Best hyperparameters:", best_hp.values)
# Out:
# 'Best hyperparameters:'
# {'num_filters': 56,
#  'kernel_size_1': 47,
#  'kernel_size_2': 70,
#  'num_heads': 3,
#  'key_dim': 12,
#  'dense_units': 16,
#  'dropout_rate': 0.30000000000000004,
#  'learning_rate': 0.0009021221727276136}

# %%
best_model = tuner.hypermodel.build(best_hp)

# %%
EPOCHS = 50

log_dir = "logs/fit23/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(
    log_dir=log_dir,
    histogram_freq=1
)

reduce_lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,       # How much to reduce LR by
    patience=3,       # Wait 3 epochs with no improvement before reducing LR
    min_lr=1e-7,      # Lower bound on LR
    cooldown=0,
    verbose=1
)

early_stop_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,       # Number of epochs with no improvement after which training stops
    restore_best_weights=True,  # Revert to the best weights found during training
    verbose=1
)

history = best_model.fit(
    train_ds,
    epochs=EPOCHS,
    steps_per_epoch=steps_per_epoch,
    validation_data=val_ds,
    validation_steps=validation_steps,
    callbacks=[
        tensorboard_callback,
        reduce_lr_callback,
        early_stop_callback
    ]
)
# Out:
# Epoch 1/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 81s 57ms/step - loss: 0.8704 - main_chemical_output_loss: 0.1523 - other_chemical_output_loss: 0.2229 - physical_output_loss: 0.2313 - val_loss: 0.3346 - val_main_chemical_output_loss: 0.0443 - val_other_chemical_output_loss: 0.0736 - val_physical_output_loss: 0.1356 - learning_rate: 9.0212e-04
# Epoch 2/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 47s 54ms/step - loss: 0.3253 - main_chemical_output_loss: 0.0449 - other_chemical_output_loss: 0.0721 - physical_output_loss: 0.1274 - val_loss: 0.3082 - val_main_chemical_output_loss: 0.0431 - val_other_chemical_output_loss: 0.0651 - val_physical_output_loss: 0.1243 - learning_rate: 9.0212e-04
# Epoch 3/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 46s 53ms/step - loss: 0.2874 - main_chemical_output_loss: 0.0392 - other_chemical_output_loss: 0.0622 - physical_output_loss: 0.1156 - val_loss: 0.2722 - val_main_chemical_output_loss: 0.0375 - val_other_chemical_output_loss: 0.0589 - val_physical_output_loss: 0.1089 - learning_rate: 9.0212e-04
# Epoch 4/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 82s 94ms/step - loss: 0.2730 - main_chemical_output_loss: 0.0373 - other_chemical_output_loss: 0.0591 - physical_output_loss: 0.1098 - val_loss: 0.2713 - val_main_chemical_output_loss: 0.0387 - val_other_chemical_output_loss: 0.0590 - val_physical_output_loss: 0.1055 - learning_rate: 9.0212e-04
# Epoch 5/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 47s 54ms/step - loss: 0.2641 - main_chemical_output_loss: 0.0363 - other_chemical_output_loss: 0.0576 - physical_output_loss: 0.1051 - val_loss: 0.2787 - val_main_chemical_output_loss: 0.0375 - val_other_chemical_output_loss: 0.0584 - val_physical_output_loss: 0.1161 - learning_rate: 9.0212e-04
# Epoch 6/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 47s 54ms/step - loss: 0.2592 - main_chemical_output_loss: 0.0354 - other_chemical_output_loss: 0.0566 - physical_output_loss: 0.1035 - val_loss: 0.2660 - val_main_chemical_output_loss: 0.0356 - val_other_chemical_output_loss: 0.0570 - val_physical_output_loss: 0.1092 - learning_rate: 9.0212e-04
# Epoch 7/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 79s 91ms/step - loss: 0.2552 - main_chemical_output_loss: 0.0349 - other_chemical_output_loss: 0.0558 - physical_output_loss: 0.1017 - val_loss: 0.2585 - val_main_chemical_output_loss: 0.0353 - val_other_chemical_output_loss: 0.0556 - val_physical_output_loss: 0.1045 - learning_rate: 9.0212e-04
# Epoch 8/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 46s 52ms/step - loss: 0.2521 - main_chemical_output_loss: 0.0344 - other_chemical_output_loss: 0.0552 - physical_output_loss: 0.1005 - val_loss: 0.2532 - val_main_chemical_output_loss: 0.0343 - val_other_chemical_output_loss: 0.0559 - val_physical_output_loss: 0.1008 - learning_rate: 9.0212e-04
# Epoch 9/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 78s 89ms/step - loss: 0.2501 - main_chemical_output_loss: 0.0340 - other_chemical_output_loss: 0.0549 - physical_output_loss: 0.0997 - val_loss: 0.2519 - val_main_chemical_output_loss: 0.0347 - val_other_chemical_output_loss: 0.0561 - val_physical_output_loss: 0.0984 - learning_rate: 9.0212e-04
# Epoch 10/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 46s 52ms/step - loss: 0.2469 - main_chemical_output_loss: 0.0336 - other_chemical_output_loss: 0.0544 - physical_output_loss: 0.0982 - val_loss: 0.2536 - val_main_chemical_output_loss: 0.0346 - val_other_chemical_output_loss: 0.0550 - val_physical_output_loss: 0.1020 - learning_rate: 9.0212e-04
# Epoch 11/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 40s 46ms/step - loss: 0.2452 - main_chemical_output_loss: 0.0334 - other_chemical_output_loss: 0.0540 - physical_output_loss: 0.0975 - val_loss: 0.2666 - val_main_chemical_output_loss: 0.0360 - val_other_chemical_output_loss: 0.0557 - val_physical_output_loss: 0.1111 - learning_rate: 9.0212e-04
# Epoch 12/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 81s 93ms/step - loss: 0.2437 - main_chemical_output_loss: 0.0331 - other_chemical_output_loss: 0.0538 - physical_output_loss: 0.0969 - val_loss: 0.2506 - val_main_chemical_output_loss: 0.0347 - val_other_chemical_output_loss: 0.0552 - val_physical_output_loss: 0.0984 - learning_rate: 9.0212e-04
# Epoch 13/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 29s 34ms/step - loss: 0.2420 - main_chemical_output_loss: 0.0327 - other_chemical_output_loss: 0.0535 - physical_output_loss: 0.0964 - val_loss: 0.2491 - val_main_chemical_output_loss: 0.0347 - val_other_chemical_output_loss: 0.0545 - val_physical_output_loss: 0.0981 - learning_rate: 9.0212e-04
# Epoch 14/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 34s 39ms/step - loss: 0.2405 - main_chemical_output_loss: 0.0325 - other_chemical_output_loss: 0.0531 - physical_output_loss: 0.0958 - val_loss: 0.2490 - val_main_chemical_output_loss: 0.0347 - val_other_chemical_output_loss: 0.0545 - val_physical_output_loss: 0.0979 - learning_rate: 9.0212e-04
# Epoch 15/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 81s 94ms/step - loss: 0.2390 - main_chemical_output_loss: 0.0322 - other_chemical_output_loss: 0.0529 - physical_output_loss: 0.0953 - val_loss: 0.2460 - val_main_chemical_output_loss: 0.0343 - val_other_chemical_output_loss: 0.0542 - val_physical_output_loss: 0.0961 - learning_rate: 9.0212e-04
# Epoch 16/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 29s 33ms/step - loss: 0.2375 - main_chemical_output_loss: 0.0319 - other_chemical_output_loss: 0.0527 - physical_output_loss: 0.0946 - val_loss: 0.2575 - val_main_chemical_output_loss: 0.0360 - val_other_chemical_output_loss: 0.0556 - val_physical_output_loss: 0.1022 - learning_rate: 9.0212e-04
# Epoch 17/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 40s 46ms/step - loss: 0.2363 - main_chemical_output_loss: 0.0317 - other_chemical_output_loss: 0.0524 - physical_output_loss: 0.0943 - val_loss: 0.2505 - val_main_chemical_output_loss: 0.0347 - val_other_chemical_output_loss: 0.0548 - val_physical_output_loss: 0.0991 - learning_rate: 9.0212e-04
# Epoch 18/50
# 871/872 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2354 - main_chemical_output_loss: 0.0315 - other_chemical_output_loss: 0.0523 - physical_output_loss: 0.0940
# Epoch 18: ReduceLROnPlateau reducing learning rate to 9.021221776492894e-05.
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 41s 47ms/step - loss: 0.2354 - main_chemical_output_loss: 0.0315 - other_chemical_output_loss: 0.0523 - physical_output_loss: 0.0940 - val_loss: 0.2483 - val_main_chemical_output_loss: 0.0345 - val_other_chemical_output_loss: 0.0542 - val_physical_output_loss: 0.0980 - learning_rate: 9.0212e-04
# Epoch 19/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 45s 52ms/step - loss: 0.2271 - main_chemical_output_loss: 0.0300 - other_chemical_output_loss: 0.0509 - physical_output_loss: 0.0908 - val_loss: 0.2379 - val_main_chemical_output_loss: 0.0333 - val_other_chemical_output_loss: 0.0526 - val_physical_output_loss: 0.0924 - learning_rate: 9.0212e-05
# Epoch 20/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 81s 93ms/step - loss: 0.2236 - main_chemical_output_loss: 0.0291 - other_chemical_output_loss: 0.0503 - physical_output_loss: 0.0898 - val_loss: 0.2376 - val_main_chemical_output_loss: 0.0333 - val_other_chemical_output_loss: 0.0526 - val_physical_output_loss: 0.0922 - learning_rate: 9.0212e-05
# Epoch 21/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 29s 33ms/step - loss: 0.2225 - main_chemical_output_loss: 0.0289 - other_chemical_output_loss: 0.0501 - physical_output_loss: 0.0895 - val_loss: 0.2383 - val_main_chemical_output_loss: 0.0335 - val_other_chemical_output_loss: 0.0526 - val_physical_output_loss: 0.0924 - learning_rate: 9.0212e-05
# Epoch 22/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 34s 39ms/step - loss: 0.2219 - main_chemical_output_loss: 0.0288 - other_chemical_output_loss: 0.0500 - physical_output_loss: 0.0893 - val_loss: 0.2378 - val_main_chemical_output_loss: 0.0335 - val_other_chemical_output_loss: 0.0527 - val_physical_output_loss: 0.0919 - learning_rate: 9.0212e-05
# Epoch 23/50
# 871/872 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.2209 - main_chemical_output_loss: 0.0285 - other_chemical_output_loss: 0.0499 - physical_output_loss: 0.0891
# Epoch 23: ReduceLROnPlateau reducing learning rate to 9.021221922012046e-06.
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 80s 92ms/step - loss: 0.2209 - main_chemical_output_loss: 0.0285 - other_chemical_output_loss: 0.0499 - physical_output_loss: 0.0891 - val_loss: 0.2378 - val_main_chemical_output_loss: 0.0334 - val_other_chemical_output_loss: 0.0526 - val_physical_output_loss: 0.0921 - learning_rate: 9.0212e-05
# Epoch 24/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 41s 46ms/step - loss: 0.2197 - main_chemical_output_loss: 0.0283 - other_chemical_output_loss: 0.0497 - physical_output_loss: 0.0885 - val_loss: 0.2371 - val_main_chemical_output_loss: 0.0334 - val_other_chemical_output_loss: 0.0525 - val_physical_output_loss: 0.0916 - learning_rate: 9.0212e-06
# Epoch 25/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 28s 32ms/step - loss: 0.2192 - main_chemical_output_loss: 0.0281 - other_chemical_output_loss: 0.0496 - physical_output_loss: 0.0885 - val_loss: 0.2372 - val_main_chemical_output_loss: 0.0334 - val_other_chemical_output_loss: 0.0525 - val_physical_output_loss: 0.0916 - learning_rate: 9.0212e-06
# Epoch 26/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 41s 47ms/step - loss: 0.2189 - main_chemical_output_loss: 0.0281 - other_chemical_output_loss: 0.0495 - physical_output_loss: 0.0885 - val_loss: 0.2371 - val_main_chemical_output_loss: 0.0334 - val_other_chemical_output_loss: 0.0525 - val_physical_output_loss: 0.0916 - learning_rate: 9.0212e-06
# Epoch 27/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.2189 - main_chemical_output_loss: 0.0280 - other_chemical_output_loss: 0.0496 - physical_output_loss: 0.0885
# Epoch 27: ReduceLROnPlateau reducing learning rate to 9.021221558214166e-07.
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 81s 93ms/step - loss: 0.2189 - main_chemical_output_loss: 0.0280 - other_chemical_output_loss: 0.0496 - physical_output_loss: 0.0885 - val_loss: 0.2372 - val_main_chemical_output_loss: 0.0334 - val_other_chemical_output_loss: 0.0525 - val_physical_output_loss: 0.0916 - learning_rate: 9.0212e-06
# Epoch 28/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - loss: 0.2188 - main_chemical_output_loss: 0.0280 - other_chemical_output_loss: 0.0496 - physical_output_loss: 0.0883 - val_loss: 0.2371 - val_main_chemical_output_loss: 0.0334 - val_other_chemical_output_loss: 0.0525 - val_physical_output_loss: 0.0916 - learning_rate: 9.0212e-07
# Epoch 29/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 34s 39ms/step - loss: 0.2186 - main_chemical_output_loss: 0.0280 - other_chemical_output_loss: 0.0495 - physical_output_loss: 0.0883 - val_loss: 0.2371 - val_main_chemical_output_loss: 0.0334 - val_other_chemical_output_loss: 0.0525 - val_physical_output_loss: 0.0916 - learning_rate: 9.0212e-07
# Epoch 30/50
# 871/872 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2183 - main_chemical_output_loss: 0.0279 - other_chemical_output_loss: 0.0494 - physical_output_loss: 0.0883
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1e-07.
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 44s 51ms/step - loss: 0.2183 - main_chemical_output_loss: 0.0279 - other_chemical_output_loss: 0.0494 - physical_output_loss: 0.0883 - val_loss: 0.2371 - val_main_chemical_output_loss: 0.0334 - val_other_chemical_output_loss: 0.0525 - val_physical_output_loss: 0.0915 - learning_rate: 9.0212e-07
# Epoch 31/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 82s 94ms/step - loss: 0.2181 - main_chemical_output_loss: 0.0278 - other_chemical_output_loss: 0.0494 - physical_output_loss: 0.0884 - val_loss: 0.2371 - val_main_chemical_output_loss: 0.0334 - val_other_chemical_output_loss: 0.0525 - val_physical_output_loss: 0.0916 - learning_rate: 1.0000e-07
# Epoch 32/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 28s 33ms/step - loss: 0.2187 - main_chemical_output_loss: 0.0280 - other_chemical_output_loss: 0.0496 - physical_output_loss: 0.0883 - val_loss: 0.2371 - val_main_chemical_output_loss: 0.0334 - val_other_chemical_output_loss: 0.0525 - val_physical_output_loss: 0.0915 - learning_rate: 1.0000e-07
# Epoch 33/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 40s 46ms/step - loss: 0.2185 - main_chemical_output_loss: 0.0279 - other_chemical_output_loss: 0.0495 - physical_output_loss: 0.0884 - val_loss: 0.2371 - val_main_chemical_output_loss: 0.0334 - val_other_chemical_output_loss: 0.0525 - val_physical_output_loss: 0.0916 - learning_rate: 1.0000e-07
# Epoch 34/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 40s 46ms/step - loss: 0.2184 - main_chemical_output_loss: 0.0279 - other_chemical_output_loss: 0.0495 - physical_output_loss: 0.0883 - val_loss: 0.2371 - val_main_chemical_output_loss: 0.0334 - val_other_chemical_output_loss: 0.0525 - val_physical_output_loss: 0.0915 - learning_rate: 1.0000e-07
# Epoch 35/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 44s 51ms/step - loss: 0.2185 - main_chemical_output_loss: 0.0279 - other_chemical_output_loss: 0.0495 - physical_output_loss: 0.0884 - val_loss: 0.2371 - val_main_chemical_output_loss: 0.0334 - val_other_chemical_output_loss: 0.0525 - val_physical_output_loss: 0.0915 - learning_rate: 1.0000e-07
# Epoch 36/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 45s 52ms/step - loss: 0.2183 - main_chemical_output_loss: 0.0279 - other_chemical_output_loss: 0.0495 - physical_output_loss: 0.0883 - val_loss: 0.2371 - val_main_chemical_output_loss: 0.0334 - val_other_chemical_output_loss: 0.0525 - val_physical_output_loss: 0.0915 - learning_rate: 1.0000e-07
# Epoch 37/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 82s 94ms/step - loss: 0.2181 - main_chemical_output_loss: 0.0278 - other_chemical_output_loss: 0.0495 - physical_output_loss: 0.0883 - val_loss: 0.2371 - val_main_chemical_output_loss: 0.0334 - val_other_chemical_output_loss: 0.0525 - val_physical_output_loss: 0.0915 - learning_rate: 1.0000e-07
# Epoch 38/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 28s 33ms/step - loss: 0.2183 - main_chemical_output_loss: 0.0279 - other_chemical_output_loss: 0.0495 - physical_output_loss: 0.0884 - val_loss: 0.2371 - val_main_chemical_output_loss: 0.0334 - val_other_chemical_output_loss: 0.0525 - val_physical_output_loss: 0.0915 - learning_rate: 1.0000e-07
# Epoch 39/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 34s 39ms/step - loss: 0.2181 - main_chemical_output_loss: 0.0278 - other_chemical_output_loss: 0.0494 - physical_output_loss: 0.0884 - val_loss: 0.2371 - val_main_chemical_output_loss: 0.0334 - val_other_chemical_output_loss: 0.0525 - val_physical_output_loss: 0.0915 - learning_rate: 1.0000e-07
# Epoch 40/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 44s 51ms/step - loss: 0.2183 - main_chemical_output_loss: 0.0279 - other_chemical_output_loss: 0.0495 - physical_output_loss: 0.0883 - val_loss: 0.2371 - val_main_chemical_output_loss: 0.0334 - val_other_chemical_output_loss: 0.0525 - val_physical_output_loss: 0.0915 - learning_rate: 1.0000e-07
# Epoch 41/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 45s 52ms/step - loss: 0.2179 - main_chemical_output_loss: 0.0278 - other_chemical_output_loss: 0.0494 - physical_output_loss: 0.0883 - val_loss: 0.2371 - val_main_chemical_output_loss: 0.0334 - val_other_chemical_output_loss: 0.0525 - val_physical_output_loss: 0.0915 - learning_rate: 1.0000e-07
# Epoch 42/50
# 872/872 ━━━━━━━━━━━━━━━━━━━━ 82s 94ms/step - loss: 0.2179 - main_chemical_output_loss: 0.0278 - other_chemical_output_loss: 0.0494 - physical_output_loss: 0.0882 - val_loss: 0.2371 - val_main_chemical_output_loss: 0.0334 - val_other_chemical_output_loss: 0.0525 - val_physical_output_loss: 0.0915 - learning_rate: 1.0000e-07
# Epoch 42: early stopping
# Restoring model weights from the end of the best epoch: 37.

# %%
plt.plot(range(42), history.history["loss"], marker="o", label="train loss", color="k", markersize=4)
plt.plot(range(42), history.history["val_loss"], marker="o", label="validation loss", color="tab:gray", markersize=4)
plt.legend();

# %%
plt.plot(range(42), history.history["main_chemical_output_loss"], marker="o", label="Train Main chemical output loss", color="k", markersize=4)
plt.plot(range(42), history.history["val_main_chemical_output_loss"], marker="o", label="Val Main chemical output loss", color="k", alpha=0.5, markersize=4)

plt.plot(range(42), history.history["other_chemical_output_loss"], marker="o", ls="dashed", label="Train Other chemical output loss", color="tab:gray", markersize=4)
plt.plot(range(42), history.history["val_other_chemical_output_loss"], marker="o", ls="dashed", label="Val Other chemical output loss", color="tab:gray", alpha=0.5, markersize=4)

plt.plot(range(42), history.history["physical_output_loss"], marker="o", ls="dotted", label="Train Physical output loss", color="tab:brown", markersize=4)
plt.plot(range(42), history.history["val_physical_output_loss"], marker="o", ls="dotted", label="Val Physical output loss", color="tab:brown", alpha=0.5, markersize=4)

plt.legend();

# %%
y_true_phys_all = []
y_true_main_chem_all = []
y_true_other_chem_all = []

y_pred_phys_all = []
y_pred_main_chem_all = []
y_pred_other_chem_all = []

for x_batch, y_batch in test_ds:
    # 1) Get model predictions for this batch
    predictions = best_model(x_batch, training=False)
    pred_phys_batch = predictions['physical_output']
    pred_main_chem_batch = predictions['main_chemical_output']
    pred_other_chem_batch = predictions['other_chemical_output']

    # 2) Collect ground-truth values
    true_phys_batch = y_batch['physical_output']
    true_main_chem_batch = y_batch['main_chemical_output']
    true_other_chem_batch = y_batch['other_chemical_output']

    # 3) Append to our running lists
    y_true_phys_all.append(true_phys_batch.numpy())
    y_true_main_chem_all.append(true_main_chem_batch.numpy())
    y_true_other_chem_all.append(true_other_chem_batch.numpy())

    y_pred_phys_all.append(pred_phys_batch.numpy())
    y_pred_main_chem_all.append(pred_main_chem_batch.numpy())
    y_pred_other_chem_all.append(pred_other_chem_batch.numpy())

# 4) Concatenate the list of batches into a single array for each head
y_true_phys_all = np.concatenate(y_true_phys_all, axis=0)
y_true_main_chem_all = np.concatenate(y_true_main_chem_all, axis=0)
y_true_other_chem_all = np.concatenate(y_true_other_chem_all, axis=0)

y_pred_phys_all = np.concatenate(y_pred_phys_all, axis=0)
y_pred_main_chem_all = np.concatenate(y_pred_main_chem_all, axis=0)
y_pred_other_chem_all = np.concatenate(y_pred_other_chem_all, axis=0)

# %%
physical_parameters = ['Radius', 'Gravity', 'Temperature', 'Pressure']
n_keys = len(physical_parameters)
n_cols = 2
n_rows = int(np.ceil(n_keys / n_cols))

plt.figure(figsize=(12, 10))

metrics_list = []

for i, phys_param in enumerate(physical_parameters):
    phys_true = np.array([y_true_phys_all[row][i] for row in range(len(y_true_phys_all))])
    phys_pred = np.array([y_pred_phys_all[row][i] for row in range(len(y_pred_phys_all))])

    min_val = min(phys_true.min(), phys_pred.min())
    max_val = max(phys_true.max(), phys_pred.max())

    r2 = r2_score(phys_true, phys_pred)

    ax = plt.subplot(n_rows, n_cols, i+1)
    ax.plot([min_val, max_val], [min_val, max_val], ls="--", color="tab:red", lw=2)

    # Compute density using a 2D histogram
    #nbins = 100
    #hist, xedges, yedges = np.histogram2d(phys_true, phys_pred, bins=nbins)
    # For each point, determine which bin it falls into
    #xidx = np.clip(np.searchsorted(xedges, phys_true) - 1, 0, nbins-1)
    #yidx = np.clip(np.searchsorted(yedges, phys_pred) - 1, 0, nbins-1)
    # Map each point to its density value (the count in its bin)
    #z = hist[xidx, yidx]

    #sc = ax.scatter(phys_true, phys_pred, c=z, s=5, cmap='Greys_r', edgecolor='none')
    ax.scatter(phys_true, phys_pred, s=10, edgecolor="tab:gray", linewidth=0.3, color="w")
    #cb = plt.colorbar(sc, ax=ax, pad=0)
    #cb.set_label("Density")

    ax.set_title(fr'{physical_parameters[i]} - $R^2$ score: {r2:.4f}')
    ax.set_xlabel("True Value")
    ax.set_ylabel("Pred Value")

    mse = mean_squared_error(phys_true, phys_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(phys_true, phys_pred)
    med_ae = median_absolute_error(phys_true, phys_pred)
    exp_var = explained_variance_score(phys_true, phys_pred)

    metrics_list.append({
        "Output": phys_param,
        "R²": r2,
        "Explained Variance": exp_var,
        "MSE": mse,
        "RMSE": rmse,
        "MAE": mae,
        "Median Absolute Error": med_ae
    })

df_metrics = pd.DataFrame(metrics_list)
plt.tight_layout();

# %%
df_metrics
# Out:
#         Output        R²  Explained Variance       MSE      RMSE       MAE  \
# 0       Radius  0.832351            0.832358  0.010842  0.104126  0.076093
# 1      Gravity  0.830790            0.830796  0.010968  0.104729  0.076574
# 2  Temperature  0.258929            0.260007  0.029153  0.170744  0.137106
# 3     Pressure  0.823935            0.824208  0.011852  0.108869  0.077090
#
#    Median Absolute Error
# 0               0.055662
# 1               0.056302
# 2               0.116770
# 3               0.053634

# %%
main_chemical_parameters = ['O2', 'O3']

n_keys = len(main_chemical_parameters)
n_cols = 2
n_rows = int(np.ceil(n_keys / n_cols))

plt.figure(figsize=(12, 6))

metrics_list = []

for i, chem_param in enumerate(main_chemical_parameters):
    chem_true = np.array([y_true_main_chem_all[row][i] for row in range(len(y_true_main_chem_all))])
    chem_pred = np.array([y_pred_main_chem_all[row][i] for row in range(len(y_pred_main_chem_all))])

    min_val = min(chem_true.min(), chem_pred.min())
    max_val = max(chem_true.max(), chem_pred.max())

    r2 = r2_score(chem_true, chem_pred)

    ax = plt.subplot(n_rows, n_cols, i+1)
    ax.plot([min_val, max_val], [min_val, max_val], ls="--", color="tab:red", lw=2)

    # Compute density using a 2D histogram
    #nbins = 50
    #hist, xedges, yedges = np.histogram2d(chem_true, chem_pred, bins=nbins)
    #xidx = np.clip(np.searchsorted(xedges, chem_true) - 1, 0, nbins-1)
    #yidx = np.clip(np.searchsorted(yedges, chem_pred) - 1, 0, nbins-1)
    #z = hist[xidx, yidx]

    # Scatter plot using density as color, with Greys_r cmap
    #sc = ax.scatter(chem_true, chem_pred, s=5, c=z, cmap='Greys_r', edgecolor="none", linewidth=0.3)
    ax.scatter(chem_true, chem_pred, s=10, edgecolor="tab:gray", linewidth=0.3, color="w")

    # Add colorbar with label "Density"
    #cb = plt.colorbar(sc, ax=ax, pad=0)
    #cb.set_label("Density")

    ax.set_title(fr'{main_chemical_parameters[i]} - $R^2$ score: {r2:.4f}')
    ax.set_xlabel("True Value")
    ax.set_ylabel("Pred Value")

    mse = mean_squared_error(chem_true, chem_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(chem_true, chem_pred)
    med_ae = median_absolute_error(chem_true, chem_pred)
    exp_var = explained_variance_score(chem_true, chem_pred)

    metrics_list.append({
        "Output": chem_param,
        "R²": r2,
        "Explained Variance": exp_var,
        "MSE": mse,
        "RMSE": rmse,
        "MAE": mae,
        "Median Absolute Error": med_ae
    })

df_metrics_chem = pd.DataFrame(metrics_list)
plt.tight_layout()
plt.show()

# %%
df_metrics_chem
# Out:
#   Output        R²  Explained Variance       MSE      RMSE       MAE  \
# 0     O2  0.822954            0.823671  0.015671  0.125184  0.062479
# 1     O3  0.954079            0.954129  0.001296  0.035995  0.010305
#
#    Median Absolute Error
# 0               0.018947
# 1               0.002228

# %%
other_chemical_parameters = ['CH4', 'CO', 'CO2', 'H2O', 'N2', 'N2O']

n_keys = len(other_chemical_parameters)
n_cols = 3
n_rows = 2
plt.figure(figsize=(14, 8))

metrics_list = []

for i, chem_param in enumerate(other_chemical_parameters):
    chem_true = np.array([y_true_other_chem_all[row][i] for row in range(len(y_true_other_chem_all))])
    chem_pred = np.array([y_pred_other_chem_all[row][i] for row in range(len(y_pred_other_chem_all))])

    # Correct min and max values using both true and pred arrays
    min_val = min(chem_true.min(), chem_pred.min())
    max_val = max(chem_true.max(), chem_pred.max())

    r2 = r2_score(chem_true, chem_pred)

    ax = plt.subplot(n_rows, n_cols, i+1)
    ax.plot([min_val, max_val], [min_val, max_val], ls="--", color="tab:red", lw=2)

    # Compute density with a 2D histogram
    #nbins = 100
    #hist, xedges, yedges = np.histogram2d(chem_true, chem_pred, bins=nbins)
    #xidx = np.clip(np.searchsorted(xedges, chem_true) - 1, 0, nbins-1)
    #yidx = np.clip(np.searchsorted(yedges, chem_pred) - 1, 0, nbins-1)
    #z = hist[xidx, yidx]

    # Create the scatter plot using density for the color (Greys_r)
    #sc = ax.scatter(chem_true, chem_pred, s=5, c=z, cmap='Greys_r', edgecolor="none", linewidth=0.3)
    ax.scatter(chem_true, chem_pred, s=10, edgecolor="tab:gray", linewidth=0.3, color="w")

    # Add a colorbar with label "Density"
    #cb = plt.colorbar(sc, ax=ax, pad=0)
    #cb.set_label("Density")

    ax.set_title(fr'{other_chemical_parameters[i]} - $R^2$ score: {r2:.4f}')
    ax.set_xlabel("True Value")
    ax.set_ylabel("Pred Value")

    mse = mean_squared_error(chem_true, chem_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(chem_true, chem_pred)
    med_ae = median_absolute_error(chem_true, chem_pred)
    exp_var = explained_variance_score(chem_true, chem_pred)

    metrics_list.append({
        "Output": chem_param,
        "R²": r2,
        "Explained Variance": exp_var,
        "MSE": mse,
        "RMSE": rmse,
        "MAE": mae,
        "Median Absolute Error": med_ae
    })

plt.tight_layout()

df_metrics_chem = pd.DataFrame(metrics_list)
plt.show()

# %%
df_metrics_chem
# Out:
#   Output        R²  Explained Variance       MSE      RMSE       MAE  \
# 0    CH4  0.858699            0.858718  0.003797  0.061617  0.039442
# 1     CO  0.695933            0.699071  0.005446  0.073800  0.053305
# 2    CO2  0.760088            0.762276  0.007461  0.086378  0.055468
# 3    H2O  0.803690            0.804032  0.002873  0.053602  0.035041
# 4     N2  0.674831            0.677851  0.034664  0.186183  0.106231
# 5    N2O  0.913024            0.913252  0.002658  0.051559  0.026989
#
#    Median Absolute Error
# 0               0.025668
# 1               0.038810
# 2               0.034289
# 3               0.022003
# 4               0.041067
# 5               0.015599

# %%
best_model.save('NN_22-tuner-habex.keras')

# %%
# Just testing
model_load = tf.keras.models.load_model("/content/drive/MyDrive/Colab Notebooks/NN_22-tuner.keras")
